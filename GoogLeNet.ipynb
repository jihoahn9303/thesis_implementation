# %% [markdown]
# ## Implementation for Inception V1 Network(GoogLeNet)
# - author: jiho Ahn
# - date: 2021.07.29
# - topic: GoogLeNet
#
# - reference link
#   - https://oi.readthedocs.io/en/latest/computer_vision/cnn/googlenet.html
#   - https://static.googleusercontent.com/media/research.google.com/ko//pubs/archive/43022.pdf
#   - https://medium.com/@rockyxu399/paper-review-and-model-architecture-for-cnn-classification-94972e40d96a
#   - https://www.tensorflow.org/guide?hl=ko
#   - https://keras.io/guides/
#   - https://www.youtube.com/watch?v=C86ZXvgpejM

# %% [markdown]
# ### Structure of GoogLeNet(Inception V1 Network)
#
# <img alt="GoogLeNet" src='https://drive.google.com/uc?export=view&id=1GbLhTFWDCC1bmmvVoXeg6GuNoqIrY3ve'>

# %% [markdown]
# ### Overall Structure of GoogLeNet(Table)
#
# <img alt="GoogLeNet(Table)" src='https://drive.google.com/uc?export=view&id=1Wf2ZZ5-3c4j_m03uyEV27tuEG_eal9SH'>
#
# ##### 논문 출처 : https://static.googleusercontent.com/media/research.google.com/ko//pubs/archive/43022.pdf

# %% [markdown]
# ### Inception layer(3a)
#
# <image alt="Detail Information for Inception Layer" src='https://drive.google.com/uc?export=view&id=1EWDUy9CzFeq98kAnjI0Q2Q4WQ5qJVgWM'>
#
# #### 출처: https://medium.com/@rockyxu399/paper-review-and-model-architecture-for-cnn-classification-94972e40d96a

# %% [markdown]
# ### Implementation

# %% [markdown]
# #### Library Import

# %%
import os

import tensorflow as tf
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dropout, Dense, Input, concatenate, GlobalAveragePooling2D, AveragePooling2D, Flatten
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import SGD
from keras.callbacks import LearningRateScheduler

import tensorflow_datasets as tfds

import cv2
import numpy as np
import math

import matplotlib

matplotlib.use('Agg')
# Loading dataset and Performing some preprocessing steps.

# %%
# number of classes for multi-class classifier
num_class = 10

# %% [markdown]
# #### Inception V1 Architecture

# %%
class Inception_v1(tf.keras.layers.Layer):
    def __init__(self, filters_1x1, filters_3x3_reduce, filters_3x3, filters_5x5_reduce, filters_5x5,
                 filters_pool_proj, name=None, kernel_init='glorot_uniform', bias_init='zeros'):
        super(Inception_v1, self).__init__()

        self.conv_1x1 = Conv2D(filters_1x1, 1, 1, 'same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)
        self.conv_3x3_reduce = Conv2D(filters_3x3_reduce, 1, 1, 'same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)
        self.conv_5x5_reduce = Conv2D(filters_5x5_reduce, 1, 1, 'same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)
        self.maxpool_3x3 = MaxPool2D(3, strides=1, padding='same')
        self.conv_3x3 = Conv2D(filters_3x3, 3, 1, 'same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)
        self.conv_5x5 = Conv2D(filters_5x5, 5, 1, 'same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)
        self.pool_proj = Conv2D(filters_pool_proj, 1, 1, 'same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)


    def call(self, x):
        result_conv_1x1 = self.conv_1x1(x)

        result_conv_3x3_reduce = self.conv_3x3_reduce(x)
        result_conv_5x5_reduce = self.conv_5x5_reduce(x)
        result_maxpool_3x3 = self.maxpool_3x3(x)

        result_conv_3x3 = self.conv_3x3(result_conv_3x3_reduce)
        result_conv_5x5 = self.conv_5x5(result_conv_5x5_reduce)
        result_pool_proj = self.pool_proj(result_maxpool_3x3)

        output = concatenate([result_conv_1x1, result_conv_3x3, result_conv_5x5, result_pool_proj], axis=-1)

        return output


    def get_config():
        config = super().get_config().copy()
        config.update({
            'conv_1x1': self.conv_1x1.get_config(),
            'conv_3x3_reduce': self.conv_3x3_reduce.get_config(),
            'conv_3x3': self.conv_3x3.get_config(),
            'conv_5x5_reduce': self.conv_5x5_reduce.get_config(),
            'conv_5x5': self.conv_5x5.get_config(),
            'conv_maxpool_3x3': self.maxpool_3x3.get_config(),
            'conv_pool_proj': self.pool_proj.get_config()
        })

        return config

# %% [markdown]
# #### Auxiliary classifier
# - 층이 깊어짐에 따라, 역전파 계산 시, 기울기 소실 문제가 발생할 가능성이 있다.
# - 따라서, 이미지와 가까운 layer들의 가중치 학습이 제대로 안되는 경우가 있다.
# - 이를 방지하고자, layer 중간에 loss를 계산하고, 이를 역전파 시키는 layer를 추가로 삽입한다.
#
# - 참고 논문 링크: https://arxiv.org/abs/1505.02496

# %%
class AuxiliaryClassifier(tf.keras.layers.Layer):
    def __init__(self):
        super(AuxiliaryClassifier, self).__init__()

        self.model = Sequential()
        self.model.add(AveragePooling2D((5, 5), strides=3, name='avg_pool_aux'))
        self.model.add(Conv2D(128, 1, padding='same', activation='relu', name='conv_aux'))
        self.model.add(Flatten())
        self.model.add(Dense(1024, activation='relu', name='dense_aux'))
        self.model.add(Dropout(rate=0.7))
        self.model.add(Dense(10, activation='softmax', name='output_aux'))


    def call(self, x):
        x = self.model(x)
        return x

    
    def get_config(self):
        config = super().get_config().copy()
        for layer in self.model.layers:
            config.update({layer['name']: layer.get_config()})

        return config

# %% [markdown]
# #### GoogLeNet Architecture

# %%
class GoogLeNet(Model):
    def __init__(self):      
        super(GoogLeNet, self).__init__()

        kernel_init = tf.keras.initializers.glorot_uniform()
        bias_init = tf.keras.initializers.Constant(value=0.2)

        self.sub_googleNet1 = Sequential()
        self.sub_googleNet1.add(Conv2D(64, 7, 2, 'same', activation='relu', name='conv1_7x7/2', kernel_initializer=kernel_init, bias_initializer=bias_init))
        self.sub_googleNet1.add(MaxPool2D(3, 2, 'same', name='maxpool1_3x3/2'))
        self.sub_googleNet1.add(Conv2D(64, 3, 1, 'same', activation='relu', name='conv2_3x3/1', kernel_initializer=kernel_init, bias_initializer=bias_init))
        self.sub_googleNet1.add(MaxPool2D(3, 2, 'same', name='maxpool2_3x3/2'))
        self.sub_googleNet1.add(Inception_v1(64, 96, 128, 16, 32, 32, 'inception_v1_3a', kernel_init, bias_init))
        self.sub_googleNet1.add(Inception_v1(128, 128, 192, 32, 96, 64, 'inception_v1_3b', kernel_init, bias_init))
        self.sub_googleNet1.add(MaxPool2D(3, 2, 'same', name='maxpool3_3x3/2'))
        self.sub_googleNet1.add(Inception_v1(192, 96, 208, 16, 48, 64, 'inception_v1_4a', kernel_init, bias_init))

        self.sub_googleNet2 = Sequential()
        self.sub_googleNet2.add(Inception_v1(160, 112, 224, 24, 64, 64, 'inception_v1_4b', kernel_init, bias_init))
        self.sub_googleNet2.add(Inception_v1(128, 128, 256, 24, 64, 64, 'inception_v1_4c', kernel_init, bias_init))
        self.sub_googleNet2.add(Inception_v1(112, 144, 288, 32, 64, 64, 'inception_v1_4d', kernel_init, bias_init))

        self.sub_googleNet3 = Sequential()
        self.sub_googleNet3.add(Inception_v1(256, 160, 320, 32, 128, 128, 'inception_v1_4e', kernel_init, bias_init))
        self.sub_googleNet3.add(MaxPool2D(3, 2, 'same', name='maxpool4_3x3/2'))
        self.sub_googleNet3.add(Inception_v1(256, 160, 320, 32, 128, 128, 'inception_v1_5a', kernel_init, bias_init))
        self.sub_googleNet3.add(Inception_v1(384, 192, 384, 48, 128, 128, 'inception_v1_5b', kernel_init, bias_init))
        self.sub_googleNet3.add(GlobalAveragePooling2D(name='global_avg_pool_7x7/1'))
        self.sub_googleNet3.add(Dropout(rate=0.4))
        self.sub_googleNet3.add(Dense(units=10, activation='softmax', name='output', kernel_initializer=kernel_init, bias_initializer=bias_init))
        
        self.aux1 = AuxiliaryClassifier()
        self.aux2 = AuxiliaryClassifier()

    
    def call(self, x):
        x1 = self.sub_googleNet1(x)

        aux1 = self.aux1(x1)
        x2 = self.sub_googleNet2(x1)

        aux2 = self.aux2(x2)
        x3 = self.sub_googleNet3(x2)

        return x3, aux1, aux2

# %% [markdown]
# #### Learning Rate Decay

# %%
lr_decay_for_epoch = LearningRateScheduler(lambda epoch: 0.01 * math.pow(0.98, math.floor((1+epoch) / 8)), verbose=1)

# %% [markdown]
# #### Load Cifar10 dataset

# %%
def load_cifar10_dataset():
    # train : image(50000, 32, 32, 3) / label(50000, 1) , test : image(10000, 32, 32, 3) / label(10000, 1)
    train_image, train_label = tfds.as_numpy(tfds.load(name='cifar10', split='train', 
                                                           as_supervised=True, shuffle_files=True, batch_size=-1))
    test_image, test_label = tfds.as_numpy(tfds.load(name='cifar10', split='test', 
                                                           as_supervised=True, shuffle_files=True, batch_size=-1))
    
    # return 2500 train sets and 500 test sets for speedy training
    train_image, train_label = train_image[0:2500, :, :, :], train_label[:2500]
    test_image, test_label = test_image[0:500, :, :, :], test_label[:500]

    # process images(resize, normalize)
    train_image = processing(train_image)
    test_image = processing(test_image)

    # transform targets to keras compatible format(One-hot encoding)
    train_label = to_categorical(train_label, num_classes=10)
    test_label = to_categorical(test_label, num_classes=10)
    
    return (train_image, train_label), (test_image, test_label)

# %% [markdown]
# #### Image processing

# %%
def processing(images):  
    # resize images
    images = np.array([cv2.resize(img, (224, 224)) for img in images[:, :, :, :]])  
    # type casting
    images = images.astype('float32') / 255.
    
    return images

# %% [markdown]
# ### Main Section

# %%
def main():
    # load images and labels
    (train_image, train_label), (test_image, test_label) = load_cifar10_dataset()

    # input layer
    input_layer = Input(shape=(224, 224, 3))

    # define model
    googlenet = GoogLeNet()
    final_output, aux1_output, aux2_output = googlenet(input_layer)
    model = Model(input_layer, [final_output, aux1_output, aux2_output], name='googLeNet')

    # set params
    epoch = 25
    initial_lrate = 0.01

    # define optimizer and learning rate scheduler
    sgd = SGD(lr=initial_lrate, momentum=0.9, nesterov=False)
    lr_sc = lr_decay_for_epoch

    # compile GoogLeNet model
    model.compile(loss=['categorical_crossentropy', 'categorical_crossentropy', 'categorical_crossentropy'],
                  loss_weights=[1, 0.3, 0.3], optimizer=sgd, metrics=['accuracy'])

    # fit and validate model
    history = model.fit(train_image, [train_label, train_label, train_label], validation_data=(test_image, [test_label, test_label, test_label]),
                        epochs=epoch, batch_size=32, callbacks=[lr_sc])

# %%
if __name__ == '__main__':
    main()
# Out:
# Downloading and preparing dataset cifar10/3.0.2 (download: 162.17 MiB, generated: 132.40 MiB, total: 294.58 MiB) to /root/tensorflow_datasets/cifar10/3.0.2...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Completed...', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Size...', max=1.0, style=ProgressSty…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Extraction completed...', max=1.0, styl…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/cifar10/3.0.2.incomplete2RGGBP/cifar10-train.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=50000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/cifar10/3.0.2.incomplete2RGGBP/cifar10-test.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=10000.0), HTML(value='')))
# Dataset cifar10 downloaded and prepared to /root/tensorflow_datasets/cifar10/3.0.2. Subsequent calls will reuse this data.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Epoch 1/25
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.01.
# 79/79 [==============================] - 48s 149ms/step - loss: 3.8402 - goog_le_net_loss: 2.4365 - goog_le_net_1_loss: 2.3373 - goog_le_net_2_loss: 2.3417 - goog_le_net_accuracy: 0.1044 - goog_le_net_1_accuracy: 0.0884 - goog_le_net_2_accuracy: 0.0952 - val_loss: 3.6939 - val_goog_le_net_loss: 2.3102 - val_goog_le_net_1_loss: 2.3024 - val_goog_le_net_2_loss: 2.3099 - val_goog_le_net_accuracy: 0.1120 - val_goog_le_net_1_accuracy: 0.1080 - val_goog_le_net_2_accuracy: 0.0980
# Epoch 2/25
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.01.
# 79/79 [==============================] - 9s 109ms/step - loss: 3.7333 - goog_le_net_loss: 2.3485 - goog_le_net_1_loss: 2.3063 - goog_le_net_2_loss: 2.3097 - goog_le_net_accuracy: 0.1004 - goog_le_net_1_accuracy: 0.0952 - goog_le_net_2_accuracy: 0.0956 - val_loss: 3.7522 - val_goog_le_net_loss: 2.3703 - val_goog_le_net_1_loss: 2.3033 - val_goog_le_net_2_loss: 2.3030 - val_goog_le_net_accuracy: 0.0980 - val_goog_le_net_1_accuracy: 0.1520 - val_goog_le_net_2_accuracy: 0.0740
# Epoch 3/25
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.01.
# 79/79 [==============================] - 9s 110ms/step - loss: 3.7209 - goog_le_net_loss: 2.3385 - goog_le_net_1_loss: 2.3030 - goog_le_net_2_loss: 2.3049 - goog_le_net_accuracy: 0.0956 - goog_le_net_1_accuracy: 0.1008 - goog_le_net_2_accuracy: 0.1020 - val_loss: 3.6996 - val_goog_le_net_loss: 2.3175 - val_goog_le_net_1_loss: 2.3036 - val_goog_le_net_2_loss: 2.3031 - val_goog_le_net_accuracy: 0.1140 - val_goog_le_net_1_accuracy: 0.0980 - val_goog_le_net_2_accuracy: 0.1140
# Epoch 4/25
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.01.
# 79/79 [==============================] - 9s 111ms/step - loss: 3.6978 - goog_le_net_loss: 2.3164 - goog_le_net_1_loss: 2.3014 - goog_le_net_2_loss: 2.3031 - goog_le_net_accuracy: 0.1100 - goog_le_net_1_accuracy: 0.1020 - goog_le_net_2_accuracy: 0.0988 - val_loss: 3.6904 - val_goog_le_net_loss: 2.3088 - val_goog_le_net_1_loss: 2.3021 - val_goog_le_net_2_loss: 2.3032 - val_goog_le_net_accuracy: 0.1160 - val_goog_le_net_1_accuracy: 0.0980 - val_goog_le_net_2_accuracy: 0.1140
# Epoch 5/25
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.01.
# 79/79 [==============================] - 9s 111ms/step - loss: 3.6633 - goog_le_net_loss: 2.2897 - goog_le_net_1_loss: 2.2911 - goog_le_net_2_loss: 2.2876 - goog_le_net_accuracy: 0.1316 - goog_le_net_1_accuracy: 0.1224 - goog_le_net_2_accuracy: 0.1312 - val_loss: 3.5564 - val_goog_le_net_loss: 2.2214 - val_goog_le_net_1_loss: 2.2404 - val_goog_le_net_2_loss: 2.2096 - val_goog_le_net_accuracy: 0.1780 - val_goog_le_net_1_accuracy: 0.1120 - val_goog_le_net_2_accuracy: 0.1780
# Epoch 6/25
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.01.
# 79/79 [==============================] - 9s 110ms/step - loss: 3.5872 - goog_le_net_loss: 2.2463 - goog_le_net_1_loss: 2.2360 - goog_le_net_2_loss: 2.2337 - goog_le_net_accuracy: 0.1436 - goog_le_net_1_accuracy: 0.1508 - goog_le_net_2_accuracy: 0.1436 - val_loss: 3.4817 - val_goog_le_net_loss: 2.1934 - val_goog_le_net_1_loss: 2.1338 - val_goog_le_net_2_loss: 2.1607 - val_goog_le_net_accuracy: 0.1760 - val_goog_le_net_1_accuracy: 0.2040 - val_goog_le_net_2_accuracy: 0.1780
# Epoch 7/25
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.01.
# 79/79 [==============================] - 9s 110ms/step - loss: 3.5357 - goog_le_net_loss: 2.2180 - goog_le_net_1_loss: 2.1939 - goog_le_net_2_loss: 2.1985 - goog_le_net_accuracy: 0.1548 - goog_le_net_1_accuracy: 0.1792 - goog_le_net_2_accuracy: 0.1708 - val_loss: 3.4412 - val_goog_le_net_loss: 2.1579 - val_goog_le_net_1_loss: 2.1311 - val_goog_le_net_2_loss: 2.1464 - val_goog_le_net_accuracy: 0.1960 - val_goog_le_net_1_accuracy: 0.2160 - val_goog_le_net_2_accuracy: 0.2020
# Epoch 8/25
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0098.
# 79/79 [==============================] - 9s 109ms/step - loss: 3.4228 - goog_le_net_loss: 2.1444 - goog_le_net_1_loss: 2.1286 - goog_le_net_2_loss: 2.1329 - goog_le_net_accuracy: 0.1796 - goog_le_net_1_accuracy: 0.1968 - goog_le_net_2_accuracy: 0.2040 - val_loss: 3.2588 - val_goog_le_net_loss: 2.0491 - val_goog_le_net_1_loss: 2.0171 - val_goog_le_net_2_loss: 2.0153 - val_goog_le_net_accuracy: 0.2340 - val_goog_le_net_1_accuracy: 0.2620 - val_goog_le_net_2_accuracy: 0.2480
# Epoch 9/25
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0098.
# 79/79 [==============================] - 9s 109ms/step - loss: 3.3732 - goog_le_net_loss: 2.1250 - goog_le_net_1_loss: 2.0718 - goog_le_net_2_loss: 2.0889 - goog_le_net_accuracy: 0.2056 - goog_le_net_1_accuracy: 0.2344 - goog_le_net_2_accuracy: 0.2200 - val_loss: 3.3506 - val_goog_le_net_loss: 2.1071 - val_goog_le_net_1_loss: 2.0620 - val_goog_le_net_2_loss: 2.0827 - val_goog_le_net_accuracy: 0.2140 - val_goog_le_net_1_accuracy: 0.2400 - val_goog_le_net_2_accuracy: 0.2420
# Epoch 10/25
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0098.
# 79/79 [==============================] - 9s 108ms/step - loss: 3.3518 - goog_le_net_loss: 2.1031 - goog_le_net_1_loss: 2.0800 - goog_le_net_2_loss: 2.0823 - goog_le_net_accuracy: 0.2072 - goog_le_net_1_accuracy: 0.2404 - goog_le_net_2_accuracy: 0.2208 - val_loss: 3.4462 - val_goog_le_net_loss: 2.2007 - val_goog_le_net_1_loss: 2.0896 - val_goog_le_net_2_loss: 2.0620 - val_goog_le_net_accuracy: 0.2060 - val_goog_le_net_1_accuracy: 0.2600 - val_goog_le_net_2_accuracy: 0.2200
# Epoch 11/25
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0098.
# 79/79 [==============================] - 9s 109ms/step - loss: 3.3281 - goog_le_net_loss: 2.0913 - goog_le_net_1_loss: 2.0623 - goog_le_net_2_loss: 2.0603 - goog_le_net_accuracy: 0.2220 - goog_le_net_1_accuracy: 0.2428 - goog_le_net_2_accuracy: 0.2416 - val_loss: 3.4196 - val_goog_le_net_loss: 2.1706 - val_goog_le_net_1_loss: 2.0668 - val_goog_le_net_2_loss: 2.0964 - val_goog_le_net_accuracy: 0.1940 - val_goog_le_net_1_accuracy: 0.2240 - val_goog_le_net_2_accuracy: 0.2540
# Epoch 12/25
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0098.
# 79/79 [==============================] - 9s 109ms/step - loss: 3.3235 - goog_le_net_loss: 2.0808 - goog_le_net_1_loss: 2.0755 - goog_le_net_2_loss: 2.0668 - goog_le_net_accuracy: 0.2288 - goog_le_net_1_accuracy: 0.2324 - goog_le_net_2_accuracy: 0.2388 - val_loss: 3.3268 - val_goog_le_net_loss: 2.0619 - val_goog_le_net_1_loss: 2.1195 - val_goog_le_net_2_loss: 2.0968 - val_goog_le_net_accuracy: 0.2240 - val_goog_le_net_1_accuracy: 0.2100 - val_goog_le_net_2_accuracy: 0.2080
# Epoch 13/25
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0098.
# 79/79 [==============================] - 9s 109ms/step - loss: 3.2936 - goog_le_net_loss: 2.0647 - goog_le_net_1_loss: 2.0680 - goog_le_net_2_loss: 2.0284 - goog_le_net_accuracy: 0.2392 - goog_le_net_1_accuracy: 0.2388 - goog_le_net_2_accuracy: 0.2524 - val_loss: 3.1583 - val_goog_le_net_loss: 1.9578 - val_goog_le_net_1_loss: 2.0356 - val_goog_le_net_2_loss: 1.9658 - val_goog_le_net_accuracy: 0.2580 - val_goog_le_net_1_accuracy: 0.2640 - val_goog_le_net_2_accuracy: 0.2940
# Epoch 14/25
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0098.
# 79/79 [==============================] - 9s 110ms/step - loss: 3.2184 - goog_le_net_loss: 2.0166 - goog_le_net_1_loss: 2.0026 - goog_le_net_2_loss: 2.0033 - goog_le_net_accuracy: 0.2572 - goog_le_net_1_accuracy: 0.2596 - goog_le_net_2_accuracy: 0.2588 - val_loss: 2.9783 - val_goog_le_net_loss: 1.8539 - val_goog_le_net_1_loss: 1.9029 - val_goog_le_net_2_loss: 1.8452 - val_goog_le_net_accuracy: 0.2980 - val_goog_le_net_1_accuracy: 0.2720 - val_goog_le_net_2_accuracy: 0.3000
# Epoch 15/25
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0098.
# 79/79 [==============================] - 9s 109ms/step - loss: 3.1555 - goog_le_net_loss: 1.9864 - goog_le_net_1_loss: 1.9555 - goog_le_net_2_loss: 1.9417 - goog_le_net_accuracy: 0.2644 - goog_le_net_1_accuracy: 0.2832 - goog_le_net_2_accuracy: 0.2796 - val_loss: 2.9353 - val_goog_le_net_loss: 1.8524 - val_goog_le_net_1_loss: 1.8012 - val_goog_le_net_2_loss: 1.8086 - val_goog_le_net_accuracy: 0.2980 - val_goog_le_net_1_accuracy: 0.3340 - val_goog_le_net_2_accuracy: 0.3200
# Epoch 16/25
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.009604.
# 79/79 [==============================] - 9s 109ms/step - loss: 3.1189 - goog_le_net_loss: 1.9691 - goog_le_net_1_loss: 1.9267 - goog_le_net_2_loss: 1.9057 - goog_le_net_accuracy: 0.2516 - goog_le_net_1_accuracy: 0.2928 - goog_le_net_2_accuracy: 0.2872 - val_loss: 3.0014 - val_goog_le_net_loss: 1.8890 - val_goog_le_net_1_loss: 1.8885 - val_goog_le_net_2_loss: 1.8195 - val_goog_le_net_accuracy: 0.2700 - val_goog_le_net_1_accuracy: 0.3260 - val_goog_le_net_2_accuracy: 0.3060
# Epoch 17/25
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.009604.
# 79/79 [==============================] - 9s 110ms/step - loss: 3.0663 - goog_le_net_loss: 1.9351 - goog_le_net_1_loss: 1.8901 - goog_le_net_2_loss: 1.8806 - goog_le_net_accuracy: 0.2928 - goog_le_net_1_accuracy: 0.3212 - goog_le_net_2_accuracy: 0.3100 - val_loss: 2.8778 - val_goog_le_net_loss: 1.8246 - val_goog_le_net_1_loss: 1.7477 - val_goog_le_net_2_loss: 1.7630 - val_goog_le_net_accuracy: 0.3180 - val_goog_le_net_1_accuracy: 0.3420 - val_goog_le_net_2_accuracy: 0.3380
# Epoch 18/25
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.009604.
# 79/79 [==============================] - 9s 110ms/step - loss: 2.9946 - goog_le_net_loss: 1.8908 - goog_le_net_1_loss: 1.8387 - goog_le_net_2_loss: 1.8408 - goog_le_net_accuracy: 0.2852 - goog_le_net_1_accuracy: 0.3176 - goog_le_net_2_accuracy: 0.3048 - val_loss: 2.8871 - val_goog_le_net_loss: 1.8141 - val_goog_le_net_1_loss: 1.8048 - val_goog_le_net_2_loss: 1.7720 - val_goog_le_net_accuracy: 0.2940 - val_goog_le_net_1_accuracy: 0.3400 - val_goog_le_net_2_accuracy: 0.3280
# Epoch 19/25
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.009604.
# 79/79 [==============================] - 9s 109ms/step - loss: 2.9915 - goog_le_net_loss: 1.8925 - goog_le_net_1_loss: 1.8322 - goog_le_net_2_loss: 1.8313 - goog_le_net_accuracy: 0.2868 - goog_le_net_1_accuracy: 0.3308 - goog_le_net_2_accuracy: 0.3140 - val_loss: 2.8849 - val_goog_le_net_loss: 1.8327 - val_goog_le_net_1_loss: 1.7505 - val_goog_le_net_2_loss: 1.7567 - val_goog_le_net_accuracy: 0.3280 - val_goog_le_net_1_accuracy: 0.3740 - val_goog_le_net_2_accuracy: 0.3400
# Epoch 20/25
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.009604.
# 79/79 [==============================] - 9s 108ms/step - loss: 2.8874 - goog_le_net_loss: 1.8274 - goog_le_net_1_loss: 1.7660 - goog_le_net_2_loss: 1.7671 - goog_le_net_accuracy: 0.2984 - goog_le_net_1_accuracy: 0.3428 - goog_le_net_2_accuracy: 0.3436 - val_loss: 3.7338 - val_goog_le_net_loss: 2.3706 - val_goog_le_net_1_loss: 2.2532 - val_goog_le_net_2_loss: 2.2907 - val_goog_le_net_accuracy: 0.1800 - val_goog_le_net_1_accuracy: 0.2160 - val_goog_le_net_2_accuracy: 0.2200
# Epoch 21/25
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.009604.
# 79/79 [==============================] - 9s 109ms/step - loss: 3.2707 - goog_le_net_loss: 2.0542 - goog_le_net_1_loss: 2.0281 - goog_le_net_2_loss: 2.0272 - goog_le_net_accuracy: 0.2508 - goog_le_net_1_accuracy: 0.2592 - goog_le_net_2_accuracy: 0.2532 - val_loss: 3.0972 - val_goog_le_net_loss: 1.9771 - val_goog_le_net_1_loss: 1.8611 - val_goog_le_net_2_loss: 1.8725 - val_goog_le_net_accuracy: 0.2720 - val_goog_le_net_1_accuracy: 0.3080 - val_goog_le_net_2_accuracy: 0.3080
# Epoch 22/25
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.009604.
# 79/79 [==============================] - 9s 109ms/step - loss: 2.9479 - goog_le_net_loss: 1.8517 - goog_le_net_1_loss: 1.8505 - goog_le_net_2_loss: 1.8034 - goog_le_net_accuracy: 0.3032 - goog_le_net_1_accuracy: 0.3224 - goog_le_net_2_accuracy: 0.3320 - val_loss: 2.7993 - val_goog_le_net_loss: 1.7742 - val_goog_le_net_1_loss: 1.6973 - val_goog_le_net_2_loss: 1.7199 - val_goog_le_net_accuracy: 0.3280 - val_goog_le_net_1_accuracy: 0.3700 - val_goog_le_net_2_accuracy: 0.3440
# Epoch 23/25
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.009604.
# 79/79 [==============================] - 9s 109ms/step - loss: 2.8481 - goog_le_net_loss: 1.7985 - goog_le_net_1_loss: 1.7557 - goog_le_net_2_loss: 1.7429 - goog_le_net_accuracy: 0.3252 - goog_le_net_1_accuracy: 0.3624 - goog_le_net_2_accuracy: 0.3600 - val_loss: 2.6770 - val_goog_le_net_loss: 1.6875 - val_goog_le_net_1_loss: 1.6613 - val_goog_le_net_2_loss: 1.6372 - val_goog_le_net_accuracy: 0.3540 - val_goog_le_net_1_accuracy: 0.3640 - val_goog_le_net_2_accuracy: 0.3620
# Epoch 24/25
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.009411919999999999.
# 79/79 [==============================] - 9s 109ms/step - loss: 2.8474 - goog_le_net_loss: 1.8014 - goog_le_net_1_loss: 1.7577 - goog_le_net_2_loss: 1.7289 - goog_le_net_accuracy: 0.3312 - goog_le_net_1_accuracy: 0.3584 - goog_le_net_2_accuracy: 0.3620 - val_loss: 2.7952 - val_goog_le_net_loss: 1.7957 - val_goog_le_net_1_loss: 1.6671 - val_goog_le_net_2_loss: 1.6646 - val_goog_le_net_accuracy: 0.3560 - val_goog_le_net_1_accuracy: 0.3740 - val_goog_le_net_2_accuracy: 0.3900
# Epoch 25/25
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.009411919999999999.
# 79/79 [==============================] - 9s 108ms/step - loss: 2.8243 - goog_le_net_loss: 1.7800 - goog_le_net_1_loss: 1.7577 - goog_le_net_2_loss: 1.7234 - goog_le_net_accuracy: 0.3380 - goog_le_net_1_accuracy: 0.3500 - goog_le_net_2_accuracy: 0.3532 - val_loss: 2.6628 - val_goog_le_net_loss: 1.6939 - val_goog_le_net_1_loss: 1.6202 - val_goog_le_net_2_loss: 1.6092 - val_goog_le_net_accuracy: 0.3680 - val_goog_le_net_1_accuracy: 0.4120 - val_goog_le_net_2_accuracy: 0.3680
